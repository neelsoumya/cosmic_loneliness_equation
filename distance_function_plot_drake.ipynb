# %% [markdown]
# <a href="https://colab.research.google.com/github/neelsoumya/cosmic_loneliness_equation/blob/main/distance_function_plot_drake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simulate the equation in Python
#
# $	\frac{4}{3} \pi  \frac{d} {  ( (d - a)^2  + b ) ^{4} } $

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
a = 1.0
b = 1.0

# Define the function
def f(d):
    numerator = (4/3) * np.pi * d
    denominator = ((d - a)**2 + b)**4
    return numerator / denominator

# Generate d values
d_values = np.linspace(-2, 4, 500)
f_values = f(d_values)

# Plot the function
plt.figure(figsize=(8, 5))
plt.plot(d_values, f_values, label=r'$f(d) = \frac{4}{3} \pi \cdot \frac{d}{((d - a)^2 + b)^4}$')
plt.axhline(1, color='gray', linestyle='--', label='y = 1')
plt.xlabel('d')
plt.ylabel('f(d)')
plt.title('Simulation of the Function')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Load google colab

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/Colab Notebooks')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Choose a = 10 and b = 5

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#plt.style.use('seaborn-whitegrid')
#sns.set_theme(style="whitegrid")
#plt.style.use('ggplot')

# Updated parameters
a = 10
b = 5

# Define the function
def f(d):
    numerator = (4/3) * np.pi * d
    denominator = ((d - a)**2 + b)**4
    return numerator / denominator

# Generate d values
d_values = np.linspace(0, 20, 500)
f_values = f(d_values)

# Plot the function
plt.figure(figsize=(8, 5))
plt.plot(d_values, f_values, label=fr'$a={a},\ b={b}$')
#plt.axhline(1, color='gray', linestyle='--', label='y = 1')
plt.xlabel('d')
plt.ylabel('f(d)')
plt.title('Simulation of $f(d) = \\frac{4}{3} \\pi \\cdot \\frac{d}{((d - a)^2 + b)^4}$')
plt.legend()
plt.grid(True)
plt.ylim(0, 0.1) # Sets the lower limit to 0 and upper limit to 0.1
plt.savefig('maxima_d_drake_v2.eps')
plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
